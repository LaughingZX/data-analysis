# %% [markdown]
# # 基础知识

# %% [markdown]
# ## 1. Python的安装

# %% [markdown]
# ### 1.1 Windows

# %% [markdown]
# **1. 安装文件下载**

# %% [markdown]
# 在Windows下安装Python3的方式有两种。
# + 一种是通过Anaconda安装，它提供了Python的科学计算环境，里面自带了Python以及常用的库。如果选用了这种方式，后面的环境配置方式会更加简便。
# + 另一种是直接下载安装包安装，即标准的安装方式。（这里主要介绍第二种）

# %% [markdown]
# 我们推荐直接下载安装包来安装，此时可以直接到官方网站下载Python 3的安装包，官方网站为：https://www.python.org/

# %% [markdown]
# 64位系统可以下载Windows x86-64 executable installer，32位系统可以下载Windows x86 executable installer

# %% [markdown]
# 双击运行下载下来的的文件。

# %% [markdown]
# **2. 环境变量配置**

# %% [markdown]
# 假如安装后的Python 3路径为D:\Program Files\Python3.6，
# + **找到环境变量：**右键点击"计算机"，然后点击"属性"，然后点击"高级系统设置"，选择"系统变量"窗口下面的"Path",双击即可！
# + **添加路径：**然后在"Path"行，添加python安装路径即可(D:\Program Files\Python3.6和D:\Program Files\Python3.6\Scripts）所以在后面，添加该路径即可。 ps：记住，路径直接用分号"；"隔开！
# + 最后设置成功以后，在cmd命令行，输入命令"python"，就可以有相关显示。

# %% [markdown]
# ### 1.2 其他的系统环境

# %% [markdown]
# 其他的系统可以参考菜鸟教程：http://www.runoob.com/python/python-install.html

# %% [markdown]
# ## 2. 编译环境

# %% [markdown]
# ### 2.1 交互式解释器

# %% [markdown]
# 你可以通过命令行窗口进入python并开始在交互式解释器中开始编写Python代码。

# %% [markdown]
# ### 2.2 Jupyter notebook

# %% [markdown]
# **安装jupyter notebook**

# %% [markdown]
# + pip install jupyter notebook

# %% [markdown]
# 输入jupyter notebook命令，查看当前jupyter指定的位置

# %% [markdown]
# **配置**

# %% [markdown]
# + jupyter notebook --generate-config

# %% [markdown]
# 执行之后会产生

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **修改jupyter_notebook_config.py配置文件**

# %% [markdown]
# 打开这个配置文件，找到“c.NotebookApp.notebook_dir=……”，把路径改成自己的工作目录。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 比如，这里要变更为

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 可以参考：https://blog.csdn.net/wang603603/article/details/78616851

# %% [markdown]
# ### 2.3 集成开发环境

# %% [markdown]
# **PyCharm**

# %% [markdown]
# 直接百度搜索[官方网站](http://www.jetbrains.com/pycharm/)，下载Community版本进行安装。

# %% [markdown]
# **其他**

# %% [markdown]
# http://python.jobbole.com/85147/

# %% [markdown]
# ## 3. 几个基本概念

# %% [markdown]
# ### 3.1 输入和输出

# %% [markdown]
# #### 3.1.1 打印输出

# %% [markdown]
# **直接输出**

# %%
print('Hello The World!')
# Out:
# Hello The World!

# %%
print('问候你大爷！')
# Out:
# 问候你大爷！

# %% [markdown]
# **变量输出**

# %%
a=15000
print(a)
# Out:
# 15000

# %%
a
# Out:
# 15000

# %% [markdown]
# **函数输出**

# %%
print(abs(-2.121)) #abs()函数的作用是取绝对值
# Out:
# 2.121

# %% [markdown]
# #### 3.1.2 输入

# %%
a = input('请输入工资：')
b = 1000
print('工资：',int(a)+b)
print(type(a))
# Out:
# 请输入工资：3000
# 工资： 4000
# <class 'str'>

# %% [markdown]
# ### 练习：
#
# + 请输入商品名称:
# + 请输入商品价格:
# + 请输入商品分类:
# + 请输入出厂日期:
# + 商品信息为：
# + 商品名称：橙子
# + 商品价格：200
# + 商品分类：水果
# + 出厂日期：2000

# %% [markdown]
# ### 3.2 注释

# %% [markdown]
# + 便于他人阅读
# + 便于自己阅读

# %% [markdown]
# **单行注释**

# %%
#这是一个注释
print('Hello The World!')
# Out:
# Hello The World!

# %% [markdown]
# **多行注释**

# %%
'''
这是一个注释
这是一个注释
这是一个注释
'''
print('Hello The World!')
# Out:
# Hello The World!

# %% [markdown]
# ### 3.3 变量

# %% [markdown]
# 变量是一个需要熟知的概念，变量代表的是某一个值得名字。简单来说，如果你希望用名字x代表3，就只需要执行下面的语句即可：

# %%
x=3
print(x)
# Out:
# 3

# %%
x*3
# Out:
# 9

# %% [markdown]
# 变量在使用之前，必须先进行赋值。变量名可以包括字母、数字和下划线（_）。变量不能以数字开头。

# %% [markdown]
# 您也可以使用del语句删除一些数字对象的引用。
# del语句的语法是：

# %%
var1 = 1
var2 = 10

# %%
del var1, var2

# %% [markdown]
# ### 3.4 运算符

# %% [markdown]
# #### 3.4.1 算术运算符

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=10
b=20
print('加法：',a+b)
print('减法：',a-b)
print('加法：',2+3)
print('乘法：',2*3)
print('除法：',10/3)
print('取模',10%3)
print('整除：',10//3)
print('n次方:',9**3)
# Out:
# 加法： 30
# 减法： -10
# 加法： 5
# 乘法： 6
# 除法： 3.3333333333333335
# 取模 1
# 整除： 3
# n次方 729

# %% [markdown]
# #### 3.4.2 比较运算符

# %% [markdown]
# 以下假设变量a为10，变量b为20：

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(1>2)
print(2==2)
print('a'=='A')
# Out:
# False
# True
# False

# %% [markdown]
# #### 3.4.3 逻辑运算符

# %% [markdown]
# Python语言支持逻辑运算符，以下假设变量 a 为 10, b为 20:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=10
b=20
print('and:',(a and b))
print('or:',(a or b))
print('not:',not(a and b))
# Out:
# and: 20
# or: 10
# not: False

# %%
print(1>2 and 1==1)
print(2==2 or 1>1)
print(not(2>3))
# Out:
# False
# True
# True

# %% [markdown]
# ### 练习
# 	1.设计一个计算器，输入3个值，数字1，运算符，数字2
# 	打印出相应结果
# 	2.分析结果
# 		print(2**(3+6)//3-20)
# 	3.年终奖计算公式：年终奖=月薪*12+绩效*50+项目奖
# 		请输入您的月薪
# 		请输入您的考勤情况(天数)
# 		请输入您的项目奖
# 		打印出
# 		您的年终奖为：
# 		您的年收入为：
# 		您的平均月收入为：

# %% [markdown]
# ### 3.5 数值

# %% [markdown]
# Python 支持三种不同的数值类型：
# + 整型(Int) - 通常被称为是整型或整数，是正或负整数，不带小数点。Python3 整型是没有限制大小的，可以当作 Long 类型使用，所以 Python3 没有 Python2 的 Long 类型。
# + 浮点型(float) - 浮点型由整数部分与小数部分组成，浮点型也可以使用科学计数法表示（2.5e2 = 2.5 x 102 = 250）
# + 复数( (complex)) - 复数由实数部分和虚数部分构成，可以用a + bj,或者complex(a,b)表示， 复数的实部a和虚部b都是浮点型。

# %% [markdown]
# 有时候，我们需要对数据内置的类型进行转换，数据类型的转换，你只需要将数据类型作为函数名即可。
# + int(x) 将x转换为一个整数。
# + float(x) 将x转换到一个浮点数。
# + complex(x) 将x转换到一个复数，实数部分为 x，虚数部分为 0。
# + complex(x, y) 将 x 和 y 转换到一个复数，实数部分为 x，虚数部分为 y。x 和 y 是数字表达式。

# %%
a=1.23
print(int(a))
# Out:
# 1

# %% [markdown]
# ### 3.6 字符串

# %% [markdown]
# #### 3.6.1 定义字符串和转义字符

# %% [markdown]
# 字符串是值，像数字一样

# %% [markdown]
# ''  单引号 和
# ""  双引号

# %%
a='Hello The World!'
print(a)
# Out:
# Hello The World!

# %%
b='"Hello!" she said'
print(b)
# Out:
# "Hello!" she said

# %% [markdown]
# 转义字符\

# %%
c='Let's go'
print(c)
# Out:
#   File "<ipython-input-13-d7645a1701ba>", line 1
#     c='Let's go'
#            ^
# SyntaxError: invalid syntax

# %%
d='Let\'s go'
print(d)
# Out:
# Let's go

# %% [markdown]
# #### 3.6.2 拼接字符串

# %%
a='黑哥'
b='么么哒'
c=a+b
print(c)
print(a,b)
# Out:
# 黑哥么么哒
# 黑哥 么么哒

# %% [markdown]
# #### 3.6.3 字符串转化

# %%
a=12345
print(a+a)
print(str(a)+str(a))
# Out:
# 24690
# 1234512345

# %% [markdown]
# #### 3.6.4 长字符串

# %%
a='''你愁啥？
瞅你咋地？
来咱俩唠唠'''

# %%
print(a)
# Out:
# 你愁啥？
# 瞅你咋地？
# 来咱俩唠唠

# %% [markdown]
# ### 4. 列表和元组

# %% [markdown]
# 列表和元组是常用的两种类型。序列是Python中最基本的数据结构。序列中的每个元素都分配一个数字 - 它的位置，或索引，第一个索引是0，第二个索引是1，依此类推。其他的内建序列还有字符串。

# %% [markdown]
# 序列都可以进行的操作包括索引，切片，加，乘，检查成员。此外，Python已经内置确定序列的长度以及确定最大和最小的元素的方法。

# %% [markdown]
# ### 4.1 通用序列操作

# %% [markdown]
# **索引**

# %%
g='wenhounidaye'
print(g[0])
# Out:
# w

# %%
print(g[-1])
# Out:
# e

# %%
num=[1,2,3,4,5,6]
print(num[3])
print(num[-2])
# Out:
# 4
# 5

# %% [markdown]
# **切片**   list的位数左边从0开始算，不包右； 右边数从-1位开始

# %%
tag='www.runoob.com'
print(tag[:3])
print(tag[-3:])
print(tag[-1])
# Out:
# www
# com
# m
# wwrno

# %%
print(tag[4:10])
bd="www.baidu.com"
print(bd[:9:2])
# Out:
# runoob
# wwbiu

# %%
num=range(0,10)
print(num)
print(num[-6:-2])
# Out:
# range(0, 10)
# range(4, 8)

# %%
print(num[::2])
# Out:
# range(0, 10, 2)

# %% [markdown]
# **拼接**

# %%
a=[1,2,3]
b=[4,5,6]
print(a+b)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# **乘法**

# %%
print(a*3)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
print('hello'*3)
# Out:
# hellohellohello

# %% [markdown]
# **成员资格** in

# %%
s='helloworld'
print('h' in s)
print('a' in s)
# Out:
# True
# False

# %%
b=['Beijing','Shanghai','Shenzhen','Guangzhou']
print('Beijing' in b)
# Out:
# True

# %% [markdown]
# #### 长度、最小值和最大值

# %%
num = [1,3,5,7,9]
print(len(num))
print(max(num))
print(min(num))
# Out:
# 5
# 9
# 1

# %% [markdown]
# ### 4.2 列表

# %%
s= list('hello')
print(s)
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %% [markdown]
# #### 4.2.1 基本列表操作

# %% [markdown]
# **元素赋值**

# %%
x=[1,1.,1]
x[1]=2
print(x)
# Out:
# [1, 2, 1]

# %% [markdown]
# **删除元素**

# %%
names=['Shanghai','Shenzhen','Guangzhou','Beijing']
del names[2]
print(names)
# Out:
# ['Shanghai', 'Shenzhen', 'Beijing']

# %% [markdown]
# #### 分片赋值

# %%
name=list('Hello')
name
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
name[2:]='w'

# %%
print(name)
# Out:
# ['H', 'e', 'w']

# %%
number = [1,5]
number[1:1]=[2,3,4]

# %%
print(number)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# #### 4.2.2 列表方法

# %% [markdown]
# 方法是一个与某些对象有紧密联系的函数，对象可能是列表、数字，也可能是字符串或者其他类型的对象，一般来说，方法可以这样进行调用：
# + 对象.方法（参数）

# %% [markdown]
# **(1) append**

# %% [markdown]
# 在列表末尾添加新的对象

# %%
lst=[1,2,3]
lst.append(4)
print(lst)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# **(2)count**

# %%
li=['to','be','or','not','to','be']
li.count('to')
print(li.count('to'))
# Out:
# 2

# %%
x=[[1,2],1,1.,[2,1,[1,2]]]
print(x.count(1))
print(x.count([1,2]))
# Out:
# 2
# 1

# %% [markdown]
# **(3)extend** 相当于拼接

# %% [markdown]
# 在列表末尾一次性追加另一个序列中的多个值（用新列表扩展原来的列表）

# %%
a=[1,2,3]
b=[4,5,6]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a=[1,2,3]
b=[4,5,6]
a=a+b
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# **(4)index**

# %% [markdown]
# 从列表中找出某个值第一个匹配项的索引位置

# %%
s=list('PYTHON')
s.index('O')
# Out:
# 4

# %%
s[4]
# Out:
# 'O'

# %% [markdown]
# **(5)insert**

# %% [markdown]
# 将对象插入列表

# %%
s.insert(4,'Shenzhen')

# %%
s
# Out:
# ['P', 'Y', 'T', 'H', 'Shenzhen', 'O', 'N']

# %% [markdown]
# **(6)pop**

# %% [markdown]
# 移除列表中的一个元素（默认最后一个元素），并且返回该元素的值

# %%
c=[1,2,3,4,5]
c.pop()
# Out:
# 5

# %%
c
# Out:
# [1, 2, 3, 4]

# %%
c.pop(0)
# Out:
# 1

# %% [markdown]
# **(7)remove**

# %% [markdown]
# 移除列表中某个值的第一个匹配项

# %%
names=['Shenzhen','Shanghai','Shenzhen','Guangzhou','Beijing']
names.remove('Shenzhen')
names
# Out:
# ['Shanghai', 'Shenzhen', 'Guangzhou', 'Beijing']

# %%
names.remove('Shenzhen')
names
# Out:
# ['Shanghai', 'Guangzhou', 'Beijing']

# %% [markdown]
# **(8)reverse**  反向排序

# %% [markdown]
# 反向列表中元素

# %%
a=[1,2,3]
a.reverse()
print(a)
# Out:
# [3, 2, 1]

# %%
a=[3,5,1,9]
a.sort(re)
print(a)
# Out:
# [9, 5, 3, 1]

# %% [markdown]
# **(9)sort**

# %% [markdown]
# 对原列表进行排序

# %%
d=[3,1,7,5,9]
d.sort()
d
# Out:
# [1, 3, 5, 7, 9]

# %%
d.reverse()
d
# Out:
# [1, 3, 5, 7, 9]

# %%
e=[3,1,7,5,9]
e.sort(reverse=True)
e
# Out:
# [9, 7, 5, 3, 1]

# %% [markdown]
# **(10)clear**

# %% [markdown]
# 清空列表

# %%
e.clear()
e
# Out:
# []

# %%
x=[1,2,3]
y=x.copy()
y
# Out:
# [1, 2, 3]

# %% [markdown]
# ### 4.3 元组

# %% [markdown]
# 元组和列表一样，也是一种序列，唯一不同的是，元组不能修改。

# %%
a=(1,2,3,4)
a
# Out:
# (1, 2, 3, 4)

# %%
b=tuple([1,2,3,4])
b
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# 元组是序列，可以进行索引、切片、取最大值、最小值和长度等序列的操作

# %%
print(b[0])
print(b[1:4])
# Out:
# 1
# (2, 3, 4)

# %% [markdown]
# 在常规的操作中列表能够完成大部分的工作，因为列表可以自由的增删改。那么元组的意义何在？

# %% [markdown]
# + 元组可以在映射当中当键使用，而列表不行
# + 元组作为很多函数的返回值存在，所以不可避免的对元组进行处理。

# %%
def op(a,b):
    s=a+b
    c=a*b
    return s,c

# %%
a=op(2,3)
print(a)
b=list(a)
b.reverse()
print(tuple(b))
# Out:
# (5, 6)
# (6, 5)

# %% [markdown]
# ### 4.4 集合 set

# %% [markdown]
# 集合是一个无序的，不重复的数据组合，它的主要作用如下：
# + 去重，把一个列表变成集合，就自动去重了
# + 关系测试，测试两组数据之前的交集、差集、并集等关系

# %%
list_1 = [1,3,4,7,3,6,7,9]
list_1=set(list_1)
print(list_1)
# Out:
# {1, 3, 4, 6, 7, 9}

# %%
set_2={1,1,2,2,2,3}
print(set_2)
# Out:
# {1, 2, 3}

# %%
list_1=set([1,3,4,7,3,6,7,9])
list_2 = set([2,6,0,66,22,8,4])

# %% [markdown]
# **交集** intersection

# %%
print(list_1.intersection(list_2))
# Out:
# {4, 6}

# %% [markdown]
# **并集** union

# %%
print(list_1.union(list_2))
# Out:
# {0, 1, 2, 3, 4, 66, 6, 7, 8, 9, 22}

# %% [markdown]
# **差集**（把list_1里面有的而list_2里面没有的取出来）

# %%
print(list_1.difference(list_2))
# Out:
# {1, 3, 9, 7}

# %% [markdown]
# #元祖
# +定义：（）、tuple
# +索引，切片，len()
# +意义：dict-key: 内置函数、自定义函数 ——>元祖

# %% [markdown]
# #集合
# +去重: list(set(li))

# %% [markdown]
# ### 练习

# %% [markdown]
# + 创建一个列表，存入班级学生的姓名；随机输入一个姓名，
# + 并且判断输入的学生姓名是否在列表中，如果存在，则打印出来该学生的姓名;
# + 如果不存在则添加到该列表中，再打印出来。
