# %%
import pandas as pd

# %%
d = 'C:/Users/Administrator/Desktop/函数练习.xlsx'  #文件完整路径
data = pd.read_excel(d,sheet_name='Sheet3')
data.describe
# Out:
# <bound method NDFrame.describe of     项目名称   单价     票数
# 0    项目1  1.0  100.0
# 1    项目2  2.0  110.0
# 2    项目3  3.0  120.0
# 3    项目4  4.0  130.0
# 4    项目5  5.0  140.0
# 5    项目6  6.0  150.0
# 6    项目7  7.0  160.0
# 7    项目8  8.0    NaN
# 8    项目9  NaN    NaN
# 9   项目10  1.0   10.0
# 10  项目11  2.0   20.0
# 11  项目12  3.0   30.0
# 12  项目13  NaN   40.0
# 13  项目14  1.0   50.0
# 14  项目15  2.0   60.0
# 15  项目16  3.0   70.0
# 16  项目17  4.0   80.0
# 17  项目18  5.0   90.0
# 18  项目19  6.0  100.0>

# %%
data.fillna(0,inplace=True)

# %%
data['总价'] = data['单价']*data['票数']
data
# Out:
#     项目名称   单价     票数      总价
# 0    项目1  1.0  100.0   100.0
# 1    项目2  2.0  110.0   220.0
# 2    项目3  3.0  120.0   360.0
# 3    项目4  4.0  130.0   520.0
# 4    项目5  5.0  140.0   700.0
# 5    项目6  6.0  150.0   900.0
# 6    项目7  7.0  160.0  1120.0
# 7    项目8  8.0    0.0     0.0
# 8    项目9  0.0    0.0     0.0
# 9   项目10  1.0   10.0    10.0
# 10  项目11  2.0   20.0    40.0
# 11  项目12  3.0   30.0    90.0
# 12  项目13  0.0   40.0     0.0
# 13  项目14  1.0   50.0    50.0
# 14  项目15  2.0   60.0   120.0
# 15  项目16  3.0   70.0   210.0
# 16  项目17  4.0   80.0   320.0
# 17  项目18  5.0   90.0   450.0
# 18  项目19  6.0  100.0   600.0
